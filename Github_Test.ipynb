# %% [markdown]
# <a href="https://colab.research.google.com/github/Reben80/Data201-Fall2026-CRN21732/blob/main/Github_Test.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# This is part markdwon 1+1

# %%
1+1

# %%
1+2
